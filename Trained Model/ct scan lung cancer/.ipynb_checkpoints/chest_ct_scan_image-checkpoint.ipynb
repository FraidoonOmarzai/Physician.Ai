# %% [markdown]
# ## Import libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import os
import random

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Section
#
# ```
# Example of file structure
#
# Data
# └───train <- training images
# │   └───adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib
# │   │   │   ---.png
# │   │   │   ---.png
# │   │   │   ...
# │   └───large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa
# │   │   │   ---.png
# │   │   │   ---.png
# │   │   │   ...
# │   └───normal
# │   │   │   ---.png
# │   │   │   ---.png
# │   │   │   ...
# │   └───squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa
# │   │   │   ---.png
# │   │   │   ---.png
# │   │   │   ...
#
# ```

# %%
path = "/content/drive/MyDrive/Data"
for files in os.listdir(path):
    print(os.path.join(path,files))
# Out:
# /content/drive/MyDrive/Data/test
# /content/drive/MyDrive/Data/valid
# /content/drive/MyDrive/Data/train

# %%
valid_dir = "/content/drive/MyDrive/Data/valid"
test_dir = "/content/drive/MyDrive/Data/test"
train_dir = "/content/drive/MyDrive/Data/train"

# %%
for dirpath, dirnames, filenames in os.walk(train_dir):
      print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 4 directories and 0 images in '/content/drive/MyDrive/Data/train'.
# There are 0 directories and 148 images in '/content/drive/MyDrive/Data/train/normal'.
# There are 0 directories and 155 images in '/content/drive/MyDrive/Data/train/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'.
# There are 0 directories and 195 images in '/content/drive/MyDrive/Data/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'.
# There are 0 directories and 115 images in '/content/drive/MyDrive/Data/train/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'.

# %%
normal_img_path = '/content/drive/MyDrive/Data/train/normal'
print(os.listdir(normal_img_path))
# Out:
# ['11 - Copy (3).png', '12 - Copy (3).png', '11 - Copy - Copy.png', '10 - Copy.png', '12 - Copy.png', '12 (2) - Copy.png', '10 (2).png', '10 - Copy (2).png', '10 (2) - Copy.png', '10.png', '12 - Copy (2).png', '11 (2).png', '12 (2).png', '13 (2).png', '13 (2) - Copy.png', '13 - Copy - Copy.png', '12 - Copy (2) - Copy.png', '13 - Copy (3).png', '13 - Copy (2) - Copy.png', '12 - Copy - Copy.png', '12.png', '11 (2) - Copy.png', '11 - Copy (2).png', '10 - Copy (3).png', '10 - Copy - Copy.png', '11 - Copy.png', '11.png', '11 - Copy (2) - Copy.png', '13 - Copy (2).png', '10 - Copy (2) - Copy.png', '20 (2) - Copy.png', '3 - Copy.png', '18 - Copy (3).png', '3 - Copy (2) - Copy.png', '7 (2) - Copy.png', '4 - Copy (2) - Copy.png', '4 - Copy (3).png', '21 - Copy (2).png', '18 - Copy.png', '17 (2).png', '3 (2).png', '16.png', '17 - Copy (2).png', '16 (2).png', '2 - Copy (2) - Copy.png', '17 - Copy (3).png', '3 (2) - Copy.png', '5 (2) - Copy.png', '6 - Copy - Copy.png', '18 - Copy - Copy.png', '6 - Copy.png', '5 - Copy (2) - Copy.png', '18 - Copy (2) - Copy.png', '6 - Copy (2).png', '2 (2) - Copy.png', '18.png', '5 (2).png', '4.png', '7 - Copy (2) - Copy.png', '18 (2).png', '2 - Copy (3).png', '20 - Copy (2) - Copy.png', '19 - Copy - Copy.png', '5 - Copy.png', '19 (2) - Copy.png', '6 - Copy (3).png', '5.png', '3 - Copy (3).png', '20 (2).png', '17.png', '4 - Copy - Copy.png', '7 (2).png', '16 - Copy (2) - Copy.png', '20.png', '20 - Copy (3).png', '19 - Copy.png', '17 - Copy - Copy.png', '6 - Copy (2) - Copy.png', '13 - Copy.png', '2 - Copy (2).png', '13.png', '2 - Copy.png', '16 - Copy.png', '19 - Copy (3).png', '6 (2).png', '16 - Copy (2).png', '21 - Copy.png', '2 - Copy - Copy.png', '2 (2).png', '18 (2) - Copy.png', '19.png', '19 (2).png', '21 - Copy - Copy.png', '5 - Copy - Copy.png', '20 - Copy (2).png', '21 - Copy (2) - Copy.png', '16 - Copy (3).png', '4 (2) - Copy.png', '7 - Copy (3).png', '3.png', '19 - Copy (2) - Copy.png', '17 (2) - Copy.png', '5 - Copy (2).png', '4 (2).png', '7 - Copy (2).png', '19 - Copy (2).png', '20 - Copy.png', '4 - Copy (2).png', '16 - Copy - Copy.png', '3 - Copy - Copy.png', '17 - Copy.png', '2.png', '5 - Copy (3).png', '18 - Copy (2).png', '4 - Copy.png', '20 - Copy - Copy.png', '3 - Copy (2).png', '6 (2) - Copy.png', '16 (2) - Copy.png', '6.png', '17 - Copy (2) - Copy.png', 'n7 - Copy.png', '8 - Copy (3).png', 'n9 (2).jpg', '7 - Copy - Copy.png', '8 - Copy.png', 'n8 (2) - Copy.jpg', 'n7.png', 'n6 - Copy.jpg', '7.png', '8.png', 'n6 (2).jpg', 'n6 (2) - Copy.jpg', 'n8 - Copy.jpg', 'n9.jpg', 'n9 (2) - Copy.jpg', 'n6.jpg', '8 (2) - Copy.png', 'n7 (2).png', 'n9 - Copy.jpg', 'n7 (2) - Copy.png', 'n8 (2).jpg', '8 - Copy - Copy.png', '8 - Copy (2) - Copy.png', '8 - Copy (2).png', '7 - Copy.png', '8 (2).png', 'n8.jpg']

# %% [markdown]
# **display random image from train/normal path**

# %%
random_image = random.sample(os.listdir(normal_img_path), 1)
# print(random_image)

plt.figure(figsize=(14,10))
img = mpimg.imread(normal_img_path + "/" + random_image[0])
print(img.shape)
plt.imshow(img, cmap="bone");
# Out:
# (270, 393, 4)

# %%
IMG_SIZE = (224, 224)
train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 label_mode="categorical",
                                                                 image_size=IMG_SIZE)

valid_data = tf.keras.preprocessing.image_dataset_from_directory(valid_dir,
                                                                 label_mode="categorical",
                                                                 image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                label_mode="categorical",
                                                                image_size=IMG_SIZE,
                                                                shuffle=False) # don't shuffle test data for prediction analysis
# Out:
# Found 613 files belonging to 4 classes.
# Found 72 files belonging to 4 classes.
# Found 315 files belonging to 4 classes.

# %% [markdown]
# ## Train the model

# %%
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name="input_layer") 
x = base_model(inputs, training=False) 
x = layers.GlobalAveragePooling2D(name="global_average_pooling")(x)
x = layers.Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(4, activation="softmax", name="output_layer")(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling (Glo  (None, 1280)             0
#  balAveragePooling2D)
#
#  dense_15 (Dense)            (None, 128)               163968
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  output_layer (Dense)        (None, 4)                 132
#
# =================================================================
# Total params: 4,224,007
# Trainable params: 174,436
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
# Compile
model.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

# Fit
history = model.fit(train_data,
                    epochs=20,
                    validation_data=valid_data
                    )
# Out:
# Epoch 1/20
# 20/20 [==============================] - 10s 200ms/step - loss: 1.0887 - accuracy: 0.4976 - val_loss: 1.0080 - val_accuracy: 0.5556
# Epoch 2/20
# 20/20 [==============================] - 4s 129ms/step - loss: 0.8026 - accuracy: 0.6493 - val_loss: 0.8980 - val_accuracy: 0.5833
# Epoch 3/20
# 20/20 [==============================] - 4s 134ms/step - loss: 0.7019 - accuracy: 0.6819 - val_loss: 1.0138 - val_accuracy: 0.4444
# Epoch 4/20
# 20/20 [==============================] - 4s 133ms/step - loss: 0.6095 - accuracy: 0.7374 - val_loss: 1.0083 - val_accuracy: 0.4583
# Epoch 5/20
# 20/20 [==============================] - 4s 131ms/step - loss: 0.5313 - accuracy: 0.7684 - val_loss: 0.9112 - val_accuracy: 0.5833
# Epoch 6/20
# 20/20 [==============================] - 4s 133ms/step - loss: 0.4073 - accuracy: 0.8434 - val_loss: 0.8152 - val_accuracy: 0.6111
# Epoch 7/20
# 20/20 [==============================] - 4s 130ms/step - loss: 0.3933 - accuracy: 0.8483 - val_loss: 0.8830 - val_accuracy: 0.6528
# Epoch 8/20
# 20/20 [==============================] - 4s 130ms/step - loss: 0.3514 - accuracy: 0.8646 - val_loss: 0.6675 - val_accuracy: 0.7778
# Epoch 9/20
# 20/20 [==============================] - 4s 133ms/step - loss: 0.2596 - accuracy: 0.9201 - val_loss: 0.8303 - val_accuracy: 0.6806
# Epoch 10/20
# 20/20 [==============================] - 4s 131ms/step - loss: 0.2478 - accuracy: 0.9086 - val_loss: 0.7864 - val_accuracy: 0.6806
# Epoch 11/20
# 20/20 [==============================] - 4s 131ms/step - loss: 0.1858 - accuracy: 0.9413 - val_loss: 0.7425 - val_accuracy: 0.7500
# Epoch 12/20
# 20/20 [==============================] - 4s 134ms/step - loss: 0.1527 - accuracy: 0.9511 - val_loss: 0.7100 - val_accuracy: 0.7500
# Epoch 13/20
# 20/20 [==============================] - 4s 128ms/step - loss: 0.1272 - accuracy: 0.9576 - val_loss: 0.7407 - val_accuracy: 0.7917
# Epoch 14/20
# 20/20 [==============================] - 4s 129ms/step - loss: 0.1131 - accuracy: 0.9723 - val_loss: 0.7283 - val_accuracy: 0.8056
# Epoch 15/20
# 20/20 [==============================] - 4s 130ms/step - loss: 0.0732 - accuracy: 0.9853 - val_loss: 0.8459 - val_accuracy: 0.7917
# Epoch 16/20
# 20/20 [==============================] - 4s 130ms/step - loss: 0.1870 - accuracy: 0.9266 - val_loss: 0.6449 - val_accuracy: 0.7917
# Epoch 17/20
# 20/20 [==============================] - 4s 132ms/step - loss: 0.0799 - accuracy: 0.9821 - val_loss: 0.7251 - val_accuracy: 0.8333
# Epoch 18/20
# 20/20 [==============================] - 4s 132ms/step - loss: 0.1015 - accuracy: 0.9723 - val_loss: 0.7237 - val_accuracy: 0.8333
# Epoch 19/20
# 20/20 [==============================] - 4s 131ms/step - loss: 0.0588 - accuracy: 0.9804 - val_loss: 0.8038 - val_accuracy: 0.8194
# Epoch 20/20
# 20/20 [==============================] - 4s 131ms/step - loss: 0.0383 - accuracy: 0.9935 - val_loss: 0.7669 - val_accuracy: 0.8611

# %%
results_feature_extraction_model = model.evaluate(test_data)
results_feature_extraction_model
# Out:
# 10/10 [==============================] - 2s 155ms/step - loss: 0.4530 - accuracy: 0.8603
# [0.4529891610145569, 0.8603174686431885]

# %%
def plot_loss_curves(history):

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history)

# %% [markdown]
# **save the model**

# %%
model.save("ct-scan-model.h5")
